# %%
import pandas as pd

# %%
df=pd.read_csv("D:\machine_learning\Algorithms\Linear regression\AttendanceMarksSA.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Attendance  73 non-null     int64
#  1   MSE         73 non-null     int64
#  2   ESE         73 non-null     int64
# dtypes: int64(3)
# memory usage: 1.8 KB

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#     Attendance  MSE  ESE
# 0           70   10   42
# 1           92    7   39
# 2           67    3   32
# 3           82   16   50
# 4           80    9   44
# ..         ...  ...  ...
# 68          80   10   47
# 69          78    8   40
# 70          92    9   49
# 71          78   11   53
# 72          78   12   58
#
# [73 rows x 3 columns]

# %%
x=df[['Attendance','MSE']]
y=df['ESE']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train)
# Out:
# 58

# %%
len(y_train)
# Out:
# 58

# %%
df.corr()
# Out:
#             Attendance       MSE       ESE
# Attendance    1.000000 -0.080943 -0.109972
# MSE          -0.080943  1.000000  0.751530
# ESE          -0.109972  0.751530  1.000000

# %%
import matplotlib.pyplot as plt

# %%
group=df.groupby('Attendance')['ESE'].mean()
plt.scatter(group.index,group.values)

# %%
group=df.groupby('MSE')['ESE'].mean()
plt.scatter(group.index,group.values)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(34.992489034021816)

# %%
model.coef_
# Out:
# array([-0.06300392,  1.72573252])

# %%
predticed_y=model.predict(x_train)
predticed_y
# Out:
# array([43.88404378, 49.06124135, 45.79878805, 47.52452058, 47.80116303,
#        44.72772148, 40.62159048, 39.80253957, 47.52452058, 41.27625643,
#        47.52452058, 49.2502531 , 54.23843893, 47.80116303, 40.93661006,
#        44.53870973, 41.08724468, 43.75803595, 47.99017478, 39.36151216,
#        42.347323  , 39.29850824, 57.43788831, 46.23981546, 50.97598562,
#        43.75803595, 47.08349316, 41.71728384, 44.97973714, 47.08349316,
#        46.32744617, 38.26581879, 49.06124135, 50.34594646, 57.62690006,
#        40.89823293, 47.33550883, 47.99017478, 58.97460909, 46.89448142,
#        44.89210644, 51.60602478, 48.43120219, 43.88404378, 41.52827209,
#        44.85372931, 49.52689556, 49.7159073 , 47.209501  , 41.27625643,
#        44.85372931, 38.70684621, 35.94842423, 50.66096604, 51.75665941,
#        42.03230342, 55.83816362, 43.12799679])

# %%
error=y_train-predticed_y
error
# Out:
# 22    -8.884044
# 57    -0.061241
# 50     5.201212
# 33     1.475479
# 39    -2.801163
# 70     4.272279
# 16     4.378410
# 35    -0.802540
# 44     1.475479
# 61    -1.276256
# 7    -10.524521
# 56    -4.250253
# 42    -4.238439
# 30     5.198837
# 47     0.063390
# 49     5.461290
# 19    -1.087245
# 59     6.241964
# 25    -0.990175
# 40    -3.361512
# 13     2.652677
# 53     4.701492
# 3     -7.437888
# 17    -0.239815
# 38    -1.975986
# 8     -0.758036
# 58     1.916507
# 6      1.282716
# 36     4.020263
# 67     3.916507
# 54    -5.327446
# 46    -0.265819
# 71     3.938759
# 15     1.654054
# 27    -5.626900
# 41    -5.898233
# 26    -5.335509
# 48    -1.990175
# 24     5.025391
# 62     3.105519
# 66    -2.892106
# 11     9.393975
# 32     2.568798
# 69    -3.884044
# 64    -5.528272
# 37     7.146271
# 29     0.473104
# 43    -6.715907
# 68    -0.209501
# 1     -2.276256
# 52     4.146271
# 21     3.293154
# 2     -3.948424
# 23     1.339034
# 20     5.243341
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_train['Attendance'],y_train)
plt.scatter(x_train['Attendance'],predticed_y)

# %%
plt.scatter(x_train['MSE'],y_train)
plt.scatter(x_train['MSE'],predticed_y)

# %%
model.score(x_train,y_train)
# Out:
# 0.5668991732776799

# %%
model.score(x_train,predticed_y)
# Out:
# 1.0

# %%
predticed_y_test=model.predict(x_test)
predticed_y_test
# Out:
# array([45.48376847, 49.69128051, 48.15455974, 47.83954016, 60.23468741,
#        50.78697388, 43.44301637, 41.52827209, 37.48514501, 59.28962867,
#        50.66096604, 53.14274556, 44.38807511, 54.30144284, 49.43926485])

# %%
plt.scatter(x_test['Attendance'],y_test)
plt.scatter(x_test['Attendance'],predticed_y_test)

# %%
plt.scatter(x_test['MSE'],y_test)
plt.scatter(x_test['MSE'],predticed_y_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.4912014616183136

# %%
model.score(x_test,predticed_y_test)
# Out:
# 1.0

# %%
model.predict([[90,15],[50,20],[20,15],[50,20],[50,25],[30,30]])
# Out:
# c:\Users\mural\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([55.20812446, 66.35694372, 59.61839858, 66.35694372, 74.98560634,
#        84.87434728])

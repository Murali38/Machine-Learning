# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("api_key")

# %%
llm_model=ChatGoogleGenerativeAI(
    model='gemini-3.5-flash',
    api_key=api_key
)

# %%
response=llm_model.invoke('Explain Linear Regression in Machine Learning ?')

# %%
response.content[0]['text']
# Out:
# '**Linear Regression** is one of the most fundamental, simple, and widely used algorithms in Machine Learning. It belongs to the family of **Supervised Learning** and is used for **Regression tasks** (predicting a continuous, numerical value).\n\nAt its core, Linear Regression models the relationship between a **dependent variable** (target/output) and one or more **independent variables** (features/inputs) by fitting a straight line to the observed data.\n\n---\n\n### 1. The Core Idea (An Analogy)\nImagine you want to predict a house\'s price based on its size. You notice that as the size (square feet) increases, the price also increases. If you plot this data on a graph, you can draw a straight line through the points. This line allows you to predict the price of a house of *any* size, even if you don\'t have existing data for that exact size. \n\nThat straight line is the **Linear Regression line**.\n\n---\n\n### 2. The Mathematical Equation\n\n#### A. Simple Linear Regression (One input variable)\nWhen there is only one independent variable ($x$) to predict the dependent variable ($y$), the formula is:\n\n$$y = \\beta_0 + \\beta_1x + \\epsilon$$\n\n*   **$y$**: The dependent variable (e.g., House Price) – what we want to predict.\n*   **$x$**: The independent variable (e.g., House Size) – the input.\n*   **$\\beta_0$ (Intercept/Bias)**: The value of $y$ when $x = 0$ (where the line crosses the y-axis).\n*   **$\\beta_1$ (Slope/Weight/Coefficient)**: This represents the relationship. It tells us how much $y$ changes for every 1-unit change in $x$.\n*   **$\\epsilon$ (Error term/Noise)**: The difference between actual data points and the predicted line (since real-world data is never perfectly on a straight line).\n\n#### B. Multiple Linear Regression (Multiple input variables)\nIn the real world, predictions usually depend on multiple factors. For example, a house\'s price depends on size, number of bedrooms, and age. The equation becomes:\n\n$$y = \\beta_0 + \\beta_1x_1 + \\beta_2x_2 + \\dots + \\beta_nx_n + \\epsilon$$\n\n---\n\n### 3. How Does the Algorithm "Learn"?\nThe goal of Linear Regression is to find the **best-fitting line** (i.e., finding the optimal values for $\\beta_0$ and $\\beta_1$). \n\nBut how do we define the "best" line? We use a **Loss Function**.\n\n#### The Cost Function: Mean Squared Error (MSE)\nTo measure how "wrong" our line is, we calculate the distance between the actual data points ($y$) and the predicted points on our line ($\\hat{y}$). This distance is called the **residual** or **error**.\n\nThe **MSE** calculates the average of the squared errors:\n\n$$MSE = \\frac{1}{n} \\sum_{i=1}^{n} (y_i - \\hat{y}_i)^2$$\n\n*We square the errors to make them all positive and to penalize larger errors more heavily.*\n\n#### Optimization: Gradient Descent\nTo find the minimum point of the Cost Function (where the errors are lowest), ML algorithms use **Gradient Descent**. \n* Imagine you are at the top of a mountain (high error) and want to get to the bottom of the valley (lowest error). \n* Gradient Descent takes small steps downward in the direction of the steepest slope until it reaches the lowest point. \n* This process updates the values of $\\beta_0$ and $\\beta_1$ iteratively.\n\n---\n\n### 4. Key Assumptions of Linear Regression\nFor Linear Regression to provide accurate and reliable results, the dataset must satisfy these five assumptions:\n\n1.  **Linearity**: The relationship between the independent and dependent variables must be linear (a straight line).\n2.  **Independence**: The observations in the dataset must be independent of each other.\n3.  **Homoscedasticity**: The variance of residual (errors) should be constant across all levels of the independent variables.\n4.  **Normality**: The residuals/errors of the model should be normally distributed.\n5.  **No Multicollinearity**: (For Multiple Regression) The input features should not be highly correlated with each other (e.g., predictin ...

# %%
print(response.content[0]['text'])
# Out:
# **Linear Regression** is one of the most fundamental, simple, and widely used algorithms in Machine Learning. It belongs to the family of **Supervised Learning** and is used for **Regression tasks** (predicting a continuous, numerical value).
#
# At its core, Linear Regression models the relationship between a **dependent variable** (target/output) and one or more **independent variables** (features/inputs) by fitting a straight line to the observed data.
#
# ---
#
# ### 1. The Core Idea (An Analogy)
# Imagine you want to predict a house's price based on its size. You notice that as the size (square feet) increases, the price also increases. If you plot this data on a graph, you can draw a straight line through the points. This line allows you to predict the price of a house of *any* size, even if you don't have existing data for that exact size.
#
# That straight line is the **Linear Regression line**.
#
# ---
#
# ### 2. The Mathematical Equation
#
# #### A. Simple Linear Regression (One input variable)
# When there is only one independent variable ($x$) to predict the dependent variable ($y$), the formula is:
#
# $$y = \beta_0 + \beta_1x + \epsilon$$
#
# *   **$y$**: The dependent variable (e.g., House Price) – what we want to predict.
# *   **$x$**: The independent variable (e.g., House Size) – the input.
# *   **$\beta_0$ (Intercept/Bias)**: The value of $y$ when $x = 0$ (where the line crosses the y-axis).
# *   **$\beta_1$ (Slope/Weight/Coefficient)**: This represents the relationship. It tells us how much $y$ changes for every 1-unit change in $x$.
# *   **$\epsilon$ (Error term/Noise)**: The difference between actual data points and the predicted line (since real-world data is never perfectly on a straight line).
#
# #### B. Multiple Linear Regression (Multiple input variables)
# In the real world, predictions usually depend on multiple factors. For example, a house's price depends on size, number of bedrooms, and age. The equation becomes:
#
# $$y = \beta_0 + \beta_1x_1 + \beta_2x_2 + \dots + \beta_nx_n + \epsilon$$
#
# ---
#
# ### 3. How Does the Algorithm "Learn"?
# The goal of Linear Regression is to find the **best-fitting line** (i.e., finding the optimal values for $\beta_0$ and $\beta_1$).
#
# But how do we define the "best" line? We use a **Loss Function**.
#
# #### The Cost Function: Mean Squared Error (MSE)
# To measure how "wrong" our line is, we calculate the distance between the actual data points ($y$) and the predicted points on our line ($\hat{y}$). This distance is called the **residual** or **error**.
#
# The **MSE** calculates the average of the squared errors:
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
#
# *We square the errors to make them all positive and to penalize larger errors more heavily.*
#
# #### Optimization: Gradient Descent
# To find the minimum point of the Cost Function (where the errors are lowest), ML algorithms use **Gradient Descent**.
# * Imagine you are at the top of a mountain (high error) and want to get to the bottom of the valley (lowest error).
# * Gradient Descent takes small steps downward in the direction of the steepest slope until it reaches the lowest point.
# * This process updates the values of $\beta_0$ and $\beta_1$ iteratively.
#
# ---
#
# ### 4. Key Assumptions of Linear Regression
# For Linear Regression to provide accurate and reliable results, the dataset must satisfy these five assumptions:
#
# 1.  **Linearity**: The relationship between the independent and dependent variables must be linear (a straight line).
# 2.  **Independence**: The observations in the dataset must be independent of each other.
# 3.  **Homoscedasticity**: The variance of residual (errors) should be constant across all levels of the independent variables.
# 4.  **Normality**: The residuals/errors of the model should be normally distributed.
# 5.  **No Multicollinearity**: (For Multiple Regression) The input features should not be highly correlated with each other (e.g., predicting weight using height in inches and height in cm is redundant).
#
# ---
#
# ### 5. How to Evaluate the Model?
# Once trained, we need to know how good our model is. We use the following metrics:
#
# *   **Mean Absolute Error (MAE)**: The average of the absolute differences between predictions and actual values. Easy to understand.
# *   **Root Mean Squared Error (RMSE)**: The square root of MSE. It brings the error unit back to the original unit of $y$ (e.g., Dollars).
# *   **R-Squared ($R^2$ / Coefficient of Determination)**: Measures how much of the variation in the output $y$ can be explained by the input $x$. It ranges from 0 to 1.
#     *   *An $R^2$ of 0.80 means 80% of the variance in the target variable is explained by the model.*
#
# ---
#
# ### 6. Pros and Cons of Linear Regression
#
# **Advantages:**
# *   **Simple and Intuitive:** Easy to understand, interpret, and explain to non-technical stakeholders.
# *   **Fast to Train:** Computationally inexpensive compared to deep learning or complex algorithms.
# *   **Overfitting Control:** Less prone to overfitting, especially when regularized (using L1/L2 regularization like Lasso/Ridge regression).
#
# **Disadvantages:**
# *   **Assumes Linearity:** Real-world data is rarely perfectly linear. It will perform poorly on complex, non-linear datasets.
# *   **Sensitive to Outliers:** A single extreme data point (outlier) can drastically change the slope of the line, ruining the model.
# *   **Underfitting:** Can be too simple to capture complex relationships.
#
# ---
#
# ### 7. Real-World Applications
# *   **Business:** Forecasting sales or revenue for the next quarter based on marketing spend.
# *   **Finance:** Estimating the valuation of a company based on its assets and liability.
# *   **Healthcare:** Predicting a patient's blood pressure based on age, BMI, and daily salt intake.
# *   **Real Estate:** Estimating property prices based on location, size, and amenities.

# %%
print(os.getenv("api_key"))

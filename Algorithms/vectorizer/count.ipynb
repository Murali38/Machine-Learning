# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
df=pd.read_csv('spam (2).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
x=df[['v2']]
y=df['v1']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
vectorizer=CountVectorizer(stop_words=['a','the','is'])

# %%
x_train.shape
# Out:
# (4457, 1)

# %%
values=vectorizer.fit_transform(x_train['v2'])
values=values.toarray()

# %%
cols=vectorizer.get_feature_names_out()

# %%
updated_xtrain=pd.DataFrame(data=values,columns=cols)

# %%
x_test.shape
# Out:
# (1115, 1)

# %%
updated_xtest=vectorizer.transform(x_test['v2'])

# %%
updated_xtest
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 13564 stored elements and shape (1115, 7689)>

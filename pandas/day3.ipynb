# %%
import pandas as pd

# %%
df=pd.read_csv('D:\machine_learning\datasets\studentperformance.csv')

# %%
df.iloc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
df.iloc[0,1] # Row index,Column index
# Out:
# 'group B'

# %%
df.iloc[0,3]
# Out:
# 'standard'

# %%
df.iloc[2]
# Out:
# gender                                  female
# race/ethnicity                         group B
# parental level of education    master's degree
# lunch                                 standard
# test preparation course                   none
# math score                                  90
# reading score                               95
# writing score                               93
# Name: 2, dtype: object

# %%
df.iloc[[0,3]] # Returns only the rows not column as column is not mentioned
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44

# %%
df.iloc[[0,3],[1,2]] # 0 and 3 row and 1 and 2 column
# Out:
#   race/ethnicity parental level of education
# 0        group B           bachelor's degree
# 3        group A          associate's degree

# %%
df.iloc[1:3] # 1 and 2 rows , All columns
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 1               completed          69             90             88
# 2                    none          90             95             93

# %%
df.iloc[:,:] # All rows and All columns
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.iloc[:,0:3] # All rows and 0,1,2 columns
# Out:
#      gender race/ethnicity parental level of education
# 0    female        group B           bachelor's degree
# 1    female        group C                some college
# 2    female        group B             master's degree
# 3      male        group A          associate's degree
# 4      male        group C                some college
# ..      ...            ...                         ...
# 995  female        group E             master's degree
# 996    male        group C                 high school
# 997  female        group C                 high school
# 998  female        group D                some college
# 999  female        group D                some college
#
# [1000 rows x 3 columns]

# %%
#df.iloc[:,['gender']] # IndexError: .iloc requires numeric indexers, got ['gender']

# %%
df.iloc[-1] # last row
# Out:
# gender                               female
# race/ethnicity                      group D
# parental level of education    some college
# lunch                          free/reduced
# test preparation course                none
# math score                               77
# reading score                            86
# writing score                            86
# Name: 999, dtype: object

# %% [markdown]
# # LOC

# %%
df.loc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
df.loc[3,'gender'] # Can add column name
# Out:
# 'male'

# %%
# df.loc[0,3] # gives error if used integer in column value
# KeyError: 3

# %%
df.loc[:,:]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[1:3,'gender'] # in loc the end value is included
# Out:
# 1    female
# 2    female
# 3      male
# Name: gender, dtype: object

# %%
df.loc[0:,'gender':'lunch']# same as iloc, all rows but only include columns gender to lunch
# Out:
#      gender race/ethnicity parental level of education         lunch
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
# [1000 rows x 4 columns]

# %%
df.loc[:5,['gender']] # as dataframe beacuse 2D
# Out:
#    gender
# 0  female
# 1  female
# 2  female
# 3    male
# 4    male
# 5  female

# %%
df.loc[0:4,['gender','lunch']] # selects mentioned rows and the two distinct columns mentioned
# Out:
#    gender         lunch
# 0  female      standard
# 1  female      standard
# 2  female      standard
# 3    male  free/reduced
# 4    male      standard

# %%
df['gender']=='male' # returns the 1-D series
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df['gender']=='male'] #returns the all the columns where gender contains male 2-D dataftrame
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

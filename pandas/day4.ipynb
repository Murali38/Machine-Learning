# %%
import pandas as pd

# %%
df=pd.read_csv('D:\machine_learning\datasets\studentperformance.csv')

# %%
df[(df['gender']=='female') &( df['lunch']=='standard')]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %% [markdown]
# # Filter Female records those who scored above 70 in maths

# %%
df[(df['gender']=='female')&(df['math score']>70)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Male records and lunch = 'standard'

# %%
df[(df['gender']=='male') & (df['lunch']=='standard')]
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score
# 4                      none          76             78             75
# ...

# %%
df.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
'''  Unique( ) method
     Syntax:-
            df['col_name].unique()
            
            returns total unique values present in a column, should be used for categorical columns'''
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
''' nunique method 
    df['column_name].nunique
         returns total number of unique values present in the column'''
df['math score'].nunique()
# Out:
# 81

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['math score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
col_names=['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course']

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
col_names=['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course']
for i in col_names:
    print(f'{i}= {df[i].unique()}')
# Out:
# gender= ['female' 'male']
# race/ethnicity= ['group B' 'group C' 'group A' 'group D' 'group E']
# parental level of education= ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# lunch= ['standard' 'free/reduced']
# test preparation course= ['none' 'completed']

# %%
col_names=['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course']
for i in col_names:
    print(f'{i}= {df[i].nunique()}')
# Out:
# gender= 2
# race/ethnicity= 5
# parental level of education= 6
# lunch= 2
# test preparation course= 2

# %% [markdown]
# # Value_counts() returns unique value and its count
# Syntax - df[col_name].value_counts()

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
data={"age":[22,None,None ,30,60],
      'sal':[None, None, 25000,30000,40000]}
dr=pd.DataFrame(data)

# %%
dr
# Out:
#     age      sal
# 0  22.0      NaN
# 1   NaN      NaN
# 2   NaN  25000.0
# 3  30.0  30000.0
# 4  60.0  40000.0
